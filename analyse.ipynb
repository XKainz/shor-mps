# %%
import pickle
import numpy as np

# %%
with open("./pickles/to_pickle55_14.pkl","rb") as f:
        to_pickle = pickle.load(f)
to_pickle.MPO_mpo.plot_schmidt_values()
to_pickle.MPS_fat.plot_schmidt_values()
to_pickle.MPS_mpo.plot_schmidt_values()
print(to_pickle.max_bond_dim_mps_mpo,"mps_mpo")
print(to_pickle.max_bond_dim_mps_fat,"mps_fat")
print(to_pickle.max_bond_dim_mpo_mpo,"mpo_mpo")
# Out:
# 66 mps_mpo
# 66 mps_fat
# 17 mpo_mpo

# %%
import classical_shors_algorithm as csa
pickle = csa.pickle_object(35,29,2**8)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import classical_shors_algorithm as csa
#       2 pickle = csa.pickle_object(35,29,2**8)
#
# File ~/Documents/Xaver/TUM/Bachelorarbeit/shor-mps/classical_shors_algorithm.py:2
#       1 '''classical_shors_alorithm'''
# ----> 2 from qm_shors_algorithm import *
#       3 from shor_helpers import *
#       4 from to_pickle import *
#
# File ~/Documents/Xaver/TUM/Bachelorarbeit/shor-mps/qm_shors_algorithm.py:7
#       5 from MPSU import *
#       6 import matplotlib.pyplot as plt
# ----> 7 import shor_helpers as sh
#       8 import Circuits as circ
#       9 import time
#
# File ~/Documents/Xaver/TUM/Bachelorarbeit/shor-mps/shor_helpers.py:5
#       3 import math
#       4 import contfrac
# ----> 5 import miller_rabin
#       6 import numpy as np
#       8 def get_x_for_N(N):
#
# ...
