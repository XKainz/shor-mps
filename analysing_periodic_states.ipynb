# %%
import numpy as np 
import numpy_helpers as nh

# %%
r = 5 #period
q = 0 #offset
N = 8 #length

def add_zeros(x,N):
    return np.concatenate((np.zeros(N-len(x)),x))


for i in range(q,2**N-1,r):
    v = nh.number_to_binary_array(i)
    print(i,add_zeros(v,N))
# Out:
# 0 [0. 0. 0. 0. 0. 0. 0. 0.]
# 5 [0. 0. 0. 0. 0. 1. 0. 1.]
# 10 [0. 0. 0. 0. 1. 0. 1. 0.]
# 15 [0. 0. 0. 0. 1. 1. 1. 1.]
# 20 [0. 0. 0. 1. 0. 1. 0. 0.]
# 25 [0. 0. 0. 1. 1. 0. 0. 1.]
# 30 [0. 0. 0. 1. 1. 1. 1. 0.]
# 35 [0. 0. 1. 0. 0. 0. 1. 1.]
# 40 [0. 0. 1. 0. 1. 0. 0. 0.]
# 45 [0. 0. 1. 0. 1. 1. 0. 1.]
# 50 [0. 0. 1. 1. 0. 0. 1. 0.]
# 55 [0. 0. 1. 1. 0. 1. 1. 1.]
# 60 [0. 0. 1. 1. 1. 1. 0. 0.]
# 65 [0. 1. 0. 0. 0. 0. 0. 1.]
# 70 [0. 1. 0. 0. 0. 1. 1. 0.]
# 75 [0. 1. 0. 0. 1. 0. 1. 1.]
# 80 [0. 1. 0. 1. 0. 0. 0. 0.]
# 85 [0. 1. 0. 1. 0. 1. 0. 1.]
# 90 [0. 1. 0. 1. 1. 0. 1. 0.]
# 95 [0. 1. 0. 1. 1. 1. 1. 1.]
# 100 [0. 1. 1. 0. 0. 1. 0. 0.]
# 105 [0. 1. 1. 0. 1. 0. 0. 1.]
# 110 [0. 1. 1. 0. 1. 1. 1. 0.]
# 115 [0. 1. 1. 1. 0. 0. 1. 1.]
# 120 [0. 1. 1. 1. 1. 0. 0. 0.]
# 125 [0. 1. 1. 1. 1. 1. 0. 1.]
# 130 [1. 0. 0. 0. 0. 0. 1. 0.]
# 135 [1. 0. 0. 0. 0. 1. 1. 1.]
# 140 [1. 0. 0. 0. 1. 1. 0. 0.]
# 145 [1. 0. 0. 1. 0. 0. 0. 1.]
# 150 [1. 0. 0. 1. 0. 1. 1. 0.]
# ...
